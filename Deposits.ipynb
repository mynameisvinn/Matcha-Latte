# %%
from db import fetch
from tqdm import tqdm
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

# %%
query = """
SELECT amt, contests.console, contests.game_type, contests.console_game

FROM transactions

INNER JOIN contests

ON contests.winner = transactions.userid

WHERE transactions.type='D'

LIMIT 10000
"""

# %%
plt.scatter(df['amt'], df['game_type'])
plt.title('Deposit Amounts by Game Type')
# Out:
# Text(0.5, 1.0, 'Deposit Amounts by Game Type')

# %%
plt.scatter(df['amt'], df['console'])
plt.title('Deposit Amounts by Console')
# Out:
# Text(0.5, 1.0, 'Deposit Amounts by Console')

# %%
plt.scatter(df['amt'], df['console_game'])
plt.title('Deposit Amounts by Console')
# Out:
# Text(0.5, 1.0, 'Deposit Amounts by Console')

# %%
query = """
SELECT amt, users_plrs.plr

FROM transactions

INNER JOIN users_plrs

ON users_plrs.users_id = transactions.userid

WHERE transactions.type='D'

LIMIT 10000
"""
df = fetch(query)
plt.scatter(df['amt'], df['plr'])

# %%
query = """
SELECT amt, users_plrs.plr

FROM transactions

INNER JOIN users_plrs

ON users_plrs.users_id = transactions.userid

WHERE transactions.type='D'

LIMIT 35000
"""
df = fetch(query)

# %%
plt.title('')
plt.ylabel('PLR')
plt.xlabel("Deposit amount")
plt.scatter(df['amt'], df['plr'])
